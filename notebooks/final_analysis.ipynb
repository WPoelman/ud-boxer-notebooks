# %%
from pathlib import Path
import pandas as pd

starting_path = Path('data/results/rewrite')
cols = [
    "precision",
    "recall",
    "f1",
    "precision_lenient",
    "recall_lenient",
    "f1_lenient",
]

for file in starting_path.glob('**/final_*.csv'):
    items = str(file).split('/')
    split = items[-2]
    lang = items[-3]
    system = file.stem.split('_')[1]
    df = pd.read_csv(file)
    for col in cols:
        df[col] = df[col].fillna(0)

    msg = f"""
SYSTEM: {system}
LANG:   {lang}
SPLIT:  {split}

FAILED DOCS:          {len(df[df['error'].notnull()])}
FAILED DOCS %:        {100 * (len(df[df['error'].notnull()]) / len(df))}
TOTAL DOCS:           {len(df)}

AVERAGE P (strict):  {100 * df["precision"].mean():.3} ({100 * df["precision"].min():.3} - {100 * df["precision"].max():.3})
AVERAGE R (strict): {100 * df["recall"].mean():.3} ({100 * df["recall"].min():.3} - {100 * df["recall"].max():.3})
AVERAGE F1 (strict): {100 * df["f1"].mean():.3} ({100 * df["f1"].min():.3} - {100 * df["f1"].max():.3})

AVERAGE P (lenient): {100 * df["precision_lenient"].mean():.3} ({100 * df["precision_lenient"].min():.3} - {100 * df["precision_lenient"].max():.3})
AVERAGE R (lenient): {100 * df["recall_lenient"].mean():.3} ({100 * df["recall_lenient"].min():.3} - {100 * df["recall_lenient"].max():.3})
AVERAGE F1 (lenient): {100 * df["f1_lenient"].mean():.3} ({100 * df["f1_lenient"].min():.3} - {100 * df["f1_lenient"].max():.3})
    """
    print(msg)
# Out:
# SYSTEM: stanza
# LANG:   en
# SPLIT:  eval
#
# FAILED DOCS:          4
# FAILED DOCS %:        0.4830917874396135
# TOTAL DOCS:           828
#
# AVERAGE P (strict):  83.1 (0.0 - 1e+02)
# AVERAGE R (strict): 80.5 (0.0 - 1e+02)
# AVERAGE F1 (strict): 81.3 (0.0 - 1e+02)
#
# AVERAGE P (lenient): 83.6 (0.0 - 1e+02)
# AVERAGE R (lenient): 80.8 (0.0 - 1e+02)
# AVERAGE F1 (lenient): 81.6 (0.0 - 1e+02)
#
#
# SYSTEM: trankit
# LANG:   en
# SPLIT:  eval
#
# FAILED DOCS:          0
# FAILED DOCS %:        0.0
# TOTAL DOCS:           828
#
# AVERAGE P (strict):  83.6 (34.3 - 1e+02)
# AVERAGE R (strict): 80.7 (37.3 - 1e+02)
# AVERAGE F1 (strict): 81.5 (50.0 - 1e+02)
#
# AVERAGE P (lenient): 84.1 (35.1 - 1e+02)
# AVERAGE R (lenient): 81.0 (38.6 - 1e+02)
# AVERAGE F1 (lenient): 81.9 (47.6 - 1e+02)
#
#
# SYSTEM: stanza
# LANG:   en
# SPLIT:  test
#
# FAILED DOCS:          0
# FAILED DOCS %:        0.0
# TOTAL DOCS:           1044
#
# AVERAGE P (strict):  83.8 (32.0 - 1e+02)
# AVERAGE R (strict): 81.4 (40.3 - 1e+02)
# AVERAGE F1 (strict): 82.0 (36.4 - 1e+02)
#
# AVERAGE P (lenient): 84.1 (34.8 - 1e+02)
# AVERAGE R (lenient): 81.6 (37.0 - 1e+02)
# AVERAGE F1 (lenient): 82.3 (41.0 - 1e+02)
#
#
# SYSTEM: trankit
# LANG:   en
# SPLIT:  test
#
# FAILED DOCS:          0
# FAILED DOCS %:        0.0
# TOTAL DOCS:           1044
#
# AVERAGE P (strict):  83.6 (28.0 - 1e+02)
# AVERAGE R (strict): 81.1 (36.8 - 1e+02)
# AVERAGE F1 (strict): 81.8 (31.8 - 1e+02)
#
# AVERAGE P (lenient): 83.9 (31.8 - 1e+02)
# AVERAGE R (lenient): 81.2 (37.0 - 1e+02)
# AVERAGE F1 (lenient): 82.0 (35.9 - 1e+02)
#
#
# SYSTEM: stanza
# LANG:   en
# SPLIT:  dev
#
# FAILED DOCS:          3
# FAILED DOCS %:        0.25817555938037867
# TOTAL DOCS:           1162
#
# AVERAGE P (strict):  83.6 (0.0 - 1e+02)
# AVERAGE R (strict): 81.6 (0.0 - 1e+02)
# AVERAGE F1 (strict): 82.1 (0.0 - 1e+02)
#
# AVERAGE P (lenient): 84.0 (0.0 - 1e+02)
# AVERAGE R (lenient): 81.9 (0.0 - 1e+02)
# AVERAGE F1 (lenient): 82.4 (0.0 - 1e+02)
#
#
# SYSTEM: trankit
# LANG:   en
# SPLIT:  dev
#
# FAILED DOCS:          3
# FAILED DOCS %:        0.25817555938037867
# TOTAL DOCS:           1162
#
# AVERAGE P (strict):  83.7 (0.0 - 1e+02)
# AVERAGE R (strict): 81.3 (0.0 - 1e+02)
# AVERAGE F1 (strict): 81.9 (0.0 - 1e+02)
#
# AVERAGE P (lenient): 84.0 (0.0 - 1e+02)
# AVERAGE R (lenient): 81.6 (0.0 - 1e+02)
# AVERAGE F1 (lenient): 82.3 (0.0 - 1e+02)
#
#
# SYSTEM: stanza
# LANG:   nl
# SPLIT:  test
#
# FAILED DOCS:          0
# FAILED DOCS %:        0.0
# TOTAL DOCS:           491
#
# AVERAGE P (strict):  77.3 (34.8 - 1e+02)
# AVERAGE R (strict): 75.4 (38.7 - 96.6)
# AVERAGE F1 (strict): 75.8 (43.7 - 96.6)
#
# AVERAGE P (lenient): 77.6 (35.0 - 1e+02)
# AVERAGE R (lenient): 75.5 (34.1 - 96.0)
# AVERAGE F1 (lenient): 76.0 (41.6 - 96.0)
#
#
# SYSTEM: trankit
# LANG:   nl
# SPLIT:  test
#
# FAILED DOCS:          0
# FAILED DOCS %:        0.0
# TOTAL DOCS:           491
#
# AVERAGE P (strict):  77.1 (23.1 - 1e+02)
# AVERAGE R (strict): 75.6 (38.7 - 95.7)
# AVERAGE F1 (strict): 75.8 (36.0 - 95.7)
#
# AVERAGE P (lenient): 77.5 (24.2 - 1e+02)
# AVERAGE R (lenient): 75.7 (34.1 - 95.0)
# AVERAGE F1 (lenient): 76.1 (37.2 - 95.0)
#
#
# SYSTEM: stanza
# LANG:   nl
# SPLIT:  dev
#
# FAILED DOCS:          0
# FAILED DOCS %:        0.0
# TOTAL DOCS:           437
#
# AVERAGE P (strict):  78.0 (32.0 - 1e+02)
# AVERAGE R (strict): 74.5 (42.1 - 95.7)
# AVERAGE F1 (strict): 75.7 (36.4 - 95.7)
#
# AVERAGE P (lenient): 78.2 (36.4 - 1e+02)
# AVERAGE R (lenient): 74.5 (45.5 - 95.0)
# AVERAGE F1 (lenient): 75.8 (41.0 - 95.0)
#
#
# SYSTEM: trankit
# LANG:   nl
# SPLIT:  dev
#
# FAILED DOCS:          0
# FAILED DOCS %:        0.0
# TOTAL DOCS:           437
#
# AVERAGE P (strict):  77.8 (31.0 - 1e+02)
# AVERAGE R (strict): 74.8 (42.1 - 95.7)
# AVERAGE F1 (strict): 75.8 (36.4 - 95.7)
#
# AVERAGE P (lenient): 78.0 (30.0 - 1e+02)
# AVERAGE R (lenient): 74.9 (45.5 - 95.0)
# AVERAGE F1 (lenient): 76.0 (38.1 - 95.0)
#
#
# SYSTEM: stanza
# LANG:   it
# SPLIT:  test
#
# FAILED DOCS:          4
# FAILED DOCS %:        0.8676789587852495
# TOTAL DOCS:           461
#
# AVERAGE P (strict):  81.2 (0.0 - 95.7)
# AVERAGE R (strict): 76.6 (0.0 - 95.7)
# AVERAGE F1 (strict): 78.4 (0.0 - 95.7)
#
# AVERAGE P (lenient): 81.2 (0.0 - 95.0)
# AVERAGE R (lenient): 76.5 (0.0 - 95.0)
# AVERAGE F1 (lenient): 78.4 (0.0 - 95.0)
#
#
# SYSTEM: trankit
# LANG:   it
# SPLIT:  test
#
# FAILED DOCS:          0
# FAILED DOCS %:        0.0
# TOTAL DOCS:           461
#
# AVERAGE P (strict):  81.9 (24.1 - 95.7)
# AVERAGE R (strict): 77.3 (35.3 - 95.7)
# AVERAGE F1 (strict): 79.1 (29.2 - 95.7)
#
# AVERAGE P (lenient): 81.9 (28.0 - 95.0)
# AVERAGE R (lenient): 77.3 (33.3 - 95.0)
# AVERAGE F1 (lenient): 79.1 (33.3 - 95.0)
#
#
# SYSTEM: stanza
# LANG:   it
# SPLIT:  dev
#
# FAILED DOCS:          10
# FAILED DOCS %:        1.8518518518518516
# TOTAL DOCS:           540
#
# AVERAGE P (strict):  79.5 (0.0 - 95.7)
# AVERAGE R (strict): 74.2 (0.0 - 95.7)
# AVERAGE F1 (strict): 76.2 (0.0 - 95.7)
#
# AVERAGE P (lenient): 79.5 (0.0 - 95.0)
# AVERAGE R (lenient): 74.2 (0.0 - 95.0)
# AVERAGE F1 (lenient): 76.2 (0.0 - 95.0)
#
#
# SYSTEM: trankit
# LANG:   it
# SPLIT:  dev
#
# FAILED DOCS:          0
# FAILED DOCS %:        0.0
# TOTAL DOCS:           540
#
# AVERAGE P (strict):  80.8 (22.9 - 1e+02)
# AVERAGE R (strict): 76.0 (39.0 - 95.7)
# AVERAGE F1 (strict): 77.8 (29.6 - 95.7)
#
# AVERAGE P (lenient): 81.0 (26.7 - 1e+02)
# AVERAGE R (lenient): 76.0 (40.0 - 95.0)
# AVERAGE F1 (lenient): 77.9 (34.0 - 95.0)
#
#
# SYSTEM: stanza
# LANG:   de
# SPLIT:  test
#
# FAILED DOCS:          0
# FAILED DOCS %:        0.0
# TOTAL DOCS:           547
#
# AVERAGE P (strict):  80.1 (28.0 - 96.3)
# AVERAGE R (strict): 75.7 (36.8 - 95.7)
# AVERAGE F1 (strict): 77.3 (31.8 - 95.7)
#
# AVERAGE P (lenient): 79.8 (30.0 - 95.8)
# AVERAGE R (lenient): 75.3 (37.9 - 95.0)
# AVERAGE F1 (lenient): 77.0 (34.3 - 95.0)
#
#
# SYSTEM: trankit
# LANG:   de
# SPLIT:  test
#
# FAILED DOCS:          0
# FAILED DOCS %:        0.0
# TOTAL DOCS:           547
#
# AVERAGE P (strict):  79.2 (21.2 - 96.3)
# AVERAGE R (strict): 76.8 (36.8 - 95.7)
# AVERAGE F1 (strict): 77.5 (26.9 - 95.7)
#
# AVERAGE P (lenient): 79.0 (25.0 - 95.8)
# AVERAGE R (lenient): 76.4 (41.2 - 95.0)
# AVERAGE F1 (lenient): 77.3 (31.1 - 95.0)
#
#
# SYSTEM: stanza
# LANG:   de
# SPLIT:  dev
#
# FAILED DOCS:          0
# FAILED DOCS %:        0.0
# TOTAL DOCS:           558
#
# AVERAGE P (strict):  80.8 (33.3 - 95.7)
# AVERAGE R (strict): 77.2 (43.9 - 95.7)
# AVERAGE F1 (strict): 78.4 (40.9 - 95.7)
#
# AVERAGE P (lenient): 80.5 (34.8 - 95.0)
# AVERAGE R (lenient): 76.7 (42.9 - 95.0)
# AVERAGE F1 (lenient): 78.1 (42.1 - 95.0)
#
#
# SYSTEM: trankit
# LANG:   de
# SPLIT:  dev
#
# FAILED DOCS:          0
# FAILED DOCS %:        0.0
# TOTAL DOCS:           558
#
# AVERAGE P (strict):  79.9 (30.4 - 95.7)
# AVERAGE R (strict): 77.9 (36.8 - 95.7)
# AVERAGE F1 (strict): 78.4 (33.3 - 95.7)
#
# AVERAGE P (lenient): 79.7 (34.8 - 95.0)
# AVERAGE R (lenient): 77.5 (41.2 - 95.0)
# AVERAGE F1 (lenient): 78.1 (37.8 - 95.0)

# %%
import pandas as pd
starting_path = Path('data/results/seq2seq')

cols = [
    "precision",
    "recall",
    "f1",
    "precision_lenient",
    "recall_lenient",
    "f1_lenient",
]

msgs = []
final = []
for file in starting_path.glob('**/results_strict_indices_*.csv'):
    items = str(file).split('/')
    lang = items[3]
    split = items[-2]
    train = items[-1].split('results_strict_indices_')[1].replace('.csv', '')

    if lang =='en':
        continue

    df = pd.read_csv(file)
    for col in cols:
        df[col] = df[col].fillna(0)

    f1 = df["f1"].mean()
    f1_len = df["f1_lenient"].mean()

    msg = f"""
SYSTEM: seq2seq
LANG:   {lang}
TRAIN:  {train}
SPLIT:  {split}

FAILED DOCS:          {len(df[df['error'].notnull()])}
FAILED DOCS %:        {100 * (len(df[df['error'].notnull()]) / len(df))}
TOTAL DOCS:           {len(df)}

AVERAGE P (strict):  {100 * df["precision"].mean():.3} ({100 * df["precision"].min():.3} - {100 * df["precision"].max():.3})
AVERAGE R (strict): {100 * df["recall"].mean():.3} ({100 * df["recall"].min():.3} - {100 * df["recall"].max():.3})
AVERAGE F1 (strict): {100 * f1:.3} ({100 * df["f1"].min():.3} - {100 * df["f1"].max():.3})

AVERAGE P (lenient):  {100 * df["precision_lenient"].mean():.3} ({100 * df["precision_lenient"].min():.3} - {100 * df["precision_lenient"].max():.3})
AVERAGE R (lenient): {100 * df["recall_lenient"].mean():.3} ({100 * df["recall_lenient"].min():.3} - {100 * df["recall_lenient"].max():.3})
AVERAGE F1 (lenient): {100 * f1_len:.3} ({100 * df["f1_lenient"].min():.3} - {100 * df["f1_lenient"].max():.3})
    """


# AVERAGE P (ignore_sense): {100 * df["precision_lenient"].mean():.3} ({100 * df["precision_lenient"].min():.3} - {100 * df["precision_lenient"].max():.3})
# AVERAGE R (ignore_sense): {100 * df["recall_lenient"].mean():.3} ({100 * df["recall_lenient"].min():.3} - {100 * df["recall_lenient"].max():.3})
# AVERAGE F1 (ignore_sense): {100 * df["f1_lenient"].mean():.3} ({100 * df["f1_lenient"].min():.3} - {100 * df["f1_lenient"].max():.3})
    print(msg)
    final.append(' '.join([lang, train, split, f'{f1_len * 100:.3}', f'{f1 * 100:.3}']))
    msgs.append(msg)
Path('all_new_langs.txt').write_text('\n\n'.join(msgs))
Path('all_results.txt').write_text('\n'.join(sorted(final)))
# Out:
# SYSTEM: seq2seq
# LANG:   nl
# TRAIN:  gold
# SPLIT:  test
#
# FAILED DOCS:          15
# FAILED DOCS %:        3.054989816700611
# TOTAL DOCS:           491
#
# AVERAGE P (strict):  28.2 (0.0 - 82.6)
# AVERAGE R (strict): 22.7 (0.0 - 73.9)
# AVERAGE F1 (strict): 24.9 (0.0 - 73.9)
#
# AVERAGE P (lenient):  60.2 (0.0 - 82.6)
# AVERAGE R (lenient): 45.3 (0.0 - 73.9)
# AVERAGE F1 (lenient): 51.1 (0.0 - 73.9)
#
#
# SYSTEM: seq2seq
# LANG:   nl
# TRAIN:  gold_silver_bronze
# SPLIT:  test
#
# FAILED DOCS:          8
# FAILED DOCS %:        1.6293279022403258
# TOTAL DOCS:           491
#
# AVERAGE P (strict):  71.2 (0.0 - 90.9)
# AVERAGE R (strict): 69.3 (0.0 - 90.9)
# AVERAGE F1 (strict): 70.0 (0.0 - 90.9)
#
# AVERAGE P (lenient):  73.0 (0.0 - 90.9)
# AVERAGE R (lenient): 70.8 (0.0 - 90.9)
# AVERAGE F1 (lenient): 71.6 (0.0 - 90.9)
#
#
# SYSTEM: seq2seq
# LANG:   nl
# TRAIN:  gold_silver
# SPLIT:  test
#
# FAILED DOCS:          28
# FAILED DOCS %:        5.7026476578411405
# TOTAL DOCS:           491
#
# AVERAGE P (strict):  52.2 (0.0 - 90.9)
# AVERAGE R (strict): 48.1 (0.0 - 90.9)
# AVERAGE F1 (strict): 49.7 (0.0 - 90.9)
#
# AVERAGE P (lenient):  59.2 (0.0 - 90.9)
# AVERAGE R (lenient): 54.4 (0.0 - 90.9)
# AVERAGE F1 (lenient): 56.2 (0.0 - 90.9)
#
#
# SYSTEM: seq2seq
# LANG:   nl
# TRAIN:  gold
# SPLIT:  dev
#
# FAILED DOCS:          13
# FAILED DOCS %:        2.9748283752860414
# TOTAL DOCS:           437
#
# AVERAGE P (strict):  33.9 (0.0 - 82.6)
# AVERAGE R (strict): 26.4 (0.0 - 72.7)
# AVERAGE F1 (strict): 29.3 (0.0 - 73.1)
#
# AVERAGE P (lenient):  60.5 (0.0 - 82.6)
# AVERAGE R (lenient): 45.3 (0.0 - 72.7)
# AVERAGE F1 (lenient): 51.2 (0.0 - 73.1)
#
#
# SYSTEM: seq2seq
# LANG:   nl
# TRAIN:  gold_silver_bronze
# SPLIT:  dev
#
# FAILED DOCS:          10
# FAILED DOCS %:        2.2883295194508007
# TOTAL DOCS:           437
#
# AVERAGE P (strict):  71.4 (0.0 - 89.5)
# AVERAGE R (strict): 69.3 (0.0 - 89.5)
# AVERAGE F1 (strict): 70.1 (0.0 - 89.5)
#
# AVERAGE P (lenient):  73.2 (0.0 - 89.5)
# AVERAGE R (lenient): 71.0 (0.0 - 89.5)
# AVERAGE F1 (lenient): 71.9 (0.0 - 89.5)
#
#
# SYSTEM: seq2seq
# LANG:   nl
# TRAIN:  gold_silver
# SPLIT:  dev
#
# FAILED DOCS:          22
# FAILED DOCS %:        5.034324942791762
# TOTAL DOCS:           437
#
# AVERAGE P (strict):  53.1 (0.0 - 87.0)
# AVERAGE R (strict): 47.8 (0.0 - 87.0)
# AVERAGE F1 (strict): 49.7 (0.0 - 87.0)
#
# AVERAGE P (lenient):  59.7 (0.0 - 87.0)
# AVERAGE R (lenient): 53.4 (0.0 - 87.0)
# AVERAGE F1 (lenient): 55.7 (0.0 - 87.0)
#
#
# SYSTEM: seq2seq
# LANG:   it
# TRAIN:  gold
# SPLIT:  test
#
# FAILED DOCS:          4
# FAILED DOCS %:        0.8676789587852495
# TOTAL DOCS:           461
#
# AVERAGE P (strict):  47.5 (0.0 - 81.0)
# AVERAGE R (strict): 40.6 (0.0 - 73.9)
# AVERAGE F1 (strict): 43.5 (0.0 - 73.9)
#
# AVERAGE P (lenient):  61.2 (0.0 - 81.0)
# AVERAGE R (lenient): 51.6 (0.0 - 73.9)
# AVERAGE F1 (lenient): 55.7 (0.0 - 73.9)
#
#
# SYSTEM: seq2seq
# LANG:   it
# TRAIN:  gold_silver_bronze
# SPLIT:  test
#
# FAILED DOCS:          12
# FAILED DOCS %:        2.6030368763557483
# TOTAL DOCS:           461
#
# AVERAGE P (strict):  75.3 (0.0 - 88.0)
# AVERAGE R (strict): 74.2 (0.0 - 88.0)
# AVERAGE F1 (strict): 74.6 (0.0 - 88.0)
#
# AVERAGE P (lenient):  76.1 (0.0 - 88.0)
# AVERAGE R (lenient): 74.9 (0.0 - 88.0)
# AVERAGE F1 (lenient): 75.4 (0.0 - 88.0)
#
#
# SYSTEM: seq2seq
# LANG:   it
# TRAIN:  gold_silver
# SPLIT:  test
#
# FAILED DOCS:          3
# FAILED DOCS %:        0.6507592190889371
# TOTAL DOCS:           461
#
# AVERAGE P (strict):  69.7 (0.0 - 87.1)
# AVERAGE R (strict): 66.8 (0.0 - 87.1)
# AVERAGE F1 (strict): 68.0 (0.0 - 87.1)
#
# AVERAGE P (lenient):  70.8 (0.0 - 87.1)
# AVERAGE R (lenient): 67.8 (0.0 - 87.1)
# AVERAGE F1 (lenient): 69.1 (0.0 - 87.1)
#
#
# SYSTEM: seq2seq
# LANG:   it
# TRAIN:  gold
# SPLIT:  dev
#
# FAILED DOCS:          3
# FAILED DOCS %:        0.5555555555555556
# TOTAL DOCS:           540
#
# AVERAGE P (strict):  47.2 (0.0 - 76.2)
# AVERAGE R (strict): 41.1 (0.0 - 74.1)
# AVERAGE F1 (strict): 43.6 (0.0 - 72.0)
#
# AVERAGE P (lenient):  60.7 (0.0 - 76.2)
# AVERAGE R (lenient): 51.9 (0.0 - 74.1)
# AVERAGE F1 (lenient): 55.5 (0.0 - 72.0)
#
#
# SYSTEM: seq2seq
# LANG:   it
# TRAIN:  gold_silver_bronze
# SPLIT:  dev
#
# FAILED DOCS:          11
# FAILED DOCS %:        2.037037037037037
# TOTAL DOCS:           540
#
# AVERAGE P (strict):  75.9 (0.0 - 88.0)
# AVERAGE R (strict): 75.1 (0.0 - 88.2)
# AVERAGE F1 (strict): 75.3 (0.0 - 88.0)
#
# AVERAGE P (lenient):  76.2 (0.0 - 88.0)
# AVERAGE R (lenient): 75.4 (0.0 - 88.2)
# AVERAGE F1 (lenient): 75.6 (0.0 - 88.0)
#
#
# SYSTEM: seq2seq
# LANG:   it
# TRAIN:  gold_silver
# SPLIT:  dev
#
# FAILED DOCS:          4
# FAILED DOCS %:        0.7407407407407408
# TOTAL DOCS:           540
#
# AVERAGE P (strict):  67.9 (0.0 - 88.0)
# AVERAGE R (strict): 64.9 (0.0 - 88.0)
# AVERAGE F1 (strict): 66.1 (0.0 - 88.0)
#
# AVERAGE P (lenient):  69.6 (0.0 - 88.0)
# AVERAGE R (lenient): 66.4 (0.0 - 88.0)
# AVERAGE F1 (lenient): 67.6 (0.0 - 88.0)
#
#
# SYSTEM: seq2seq
# LANG:   de
# TRAIN:  gold
# SPLIT:  test
#
# FAILED DOCS:          17
# FAILED DOCS %:        3.1078610603290677
# TOTAL DOCS:           547
#
# AVERAGE P (strict):  64.3 (0.0 - 87.0)
# AVERAGE R (strict): 58.9 (0.0 - 87.0)
# AVERAGE F1 (strict): 61.1 (0.0 - 87.0)
#
# AVERAGE P (lenient):  67.2 (0.0 - 87.0)
# AVERAGE R (lenient): 61.4 (0.0 - 87.0)
# AVERAGE F1 (lenient): 63.8 (0.0 - 87.0)
#
#
# SYSTEM: seq2seq
# LANG:   de
# TRAIN:  gold_silver_bronze
# SPLIT:  test
#
# FAILED DOCS:          6
# FAILED DOCS %:        1.0968921389396709
# TOTAL DOCS:           547
#
# AVERAGE P (strict):  74.8 (0.0 - 89.5)
# AVERAGE R (strict): 74.0 (0.0 - 89.5)
# AVERAGE F1 (strict): 74.2 (0.0 - 89.5)
#
# AVERAGE P (lenient):  75.4 (0.0 - 89.5)
# AVERAGE R (lenient): 74.5 (0.0 - 89.5)
# AVERAGE F1 (lenient): 74.7 (0.0 - 89.5)
#
#
# SYSTEM: seq2seq
# LANG:   de
# TRAIN:  gold_silver
# SPLIT:  test
#
# FAILED DOCS:          12
# FAILED DOCS %:        2.1937842778793417
# TOTAL DOCS:           547
#
# AVERAGE P (strict):  67.5 (0.0 - 89.5)
# AVERAGE R (strict): 63.9 (0.0 - 89.5)
# AVERAGE F1 (strict): 65.3 (0.0 - 89.5)
#
# AVERAGE P (lenient):  70.8 (0.0 - 89.5)
# AVERAGE R (lenient): 66.7 (0.0 - 89.5)
# AVERAGE F1 (lenient): 68.3 (0.0 - 89.5)
#
#
# SYSTEM: seq2seq
# LANG:   de
# TRAIN:  gold
# SPLIT:  dev
#
# FAILED DOCS:          13
# FAILED DOCS %:        2.3297491039426523
# TOTAL DOCS:           558
#
# AVERAGE P (strict):  64.7 (0.0 - 88.0)
# AVERAGE R (strict): 59.0 (0.0 - 88.0)
# AVERAGE F1 (strict): 61.4 (0.0 - 88.0)
#
# AVERAGE P (lenient):  67.8 (0.0 - 88.0)
# AVERAGE R (lenient): 61.7 (0.0 - 88.0)
# AVERAGE F1 (lenient): 64.2 (0.0 - 88.0)
#
#
# SYSTEM: seq2seq
# LANG:   de
# TRAIN:  gold_silver_bronze
# SPLIT:  dev
#
# FAILED DOCS:          7
# FAILED DOCS %:        1.2544802867383513
# TOTAL DOCS:           558
#
# AVERAGE P (strict):  75.3 (0.0 - 88.9)
# AVERAGE R (strict): 73.9 (0.0 - 88.9)
# AVERAGE F1 (strict): 74.3 (0.0 - 88.9)
#
# AVERAGE P (lenient):  75.5 (0.0 - 88.9)
# AVERAGE R (lenient): 74.1 (0.0 - 88.9)
# AVERAGE F1 (lenient): 74.6 (0.0 - 88.9)
#
#
# SYSTEM: seq2seq
# LANG:   de
# TRAIN:  gold_silver
# SPLIT:  dev
#
# FAILED DOCS:          9
# FAILED DOCS %:        1.6129032258064515
# TOTAL DOCS:           558
#
# AVERAGE P (strict):  68.3 (0.0 - 88.0)
# AVERAGE R (strict): 64.3 (0.0 - 88.0)
# AVERAGE F1 (strict): 65.9 (0.0 - 88.0)
#
# AVERAGE P (lenient):  71.0 (0.0 - 88.0)
# AVERAGE R (lenient): 66.7 (0.0 - 88.0)
# AVERAGE F1 (lenient): 68.4 (0.0 - 88.0)
# 530

# %%
from pathlib import Path
for lang in ['de', 'nl', 'it']:
    for split in ['dev', 'test']:
        for folder in ['gold_only', 'gold_silver', 'gold_silver_bronze']:
            output_lines = Path(f'../multiling_exps/{folder}/{lang}_{split}.drs.out').read_text(errors='replace').rstrip().split('\n')
            ids = Path(f'data/splits/{lang}_{split}.txt').read_text().rstrip().split('\n')

            print(lang, split, folder)
            print(len(output_lines), len(ids))

            assert len(output_lines) == len(ids)

            # final_lines = ['id,sbn']
            final_lines = [
                f'{i},{l}'
                for i, l in zip(ids, output_lines)
            ]

            if folder == 'gold_only':
                folder = 'gold'

            Path(f'data/seq2seq/{lang}/{folder}_{split}.txt').write_text('\n'.join(final_lines))
# Out:
# de dev gold_only
# 559 559
# de dev gold_silver
# 559 559
# de dev gold_silver_bronze
# 559 559
# de test gold_only
# 547 547
# de test gold_silver
# 547 547
# de test gold_silver_bronze
# 547 547
# nl dev gold_only
# 437 437
# nl dev gold_silver
# 437 437
# nl dev gold_silver_bronze
# 437 437
# nl test gold_only
# 491 491
# nl test gold_silver
# 491 491
# nl test gold_silver_bronze
# 491 491
# it dev gold_only
# 540 540
# it dev gold_silver
# 540 540
# it dev gold_silver_bronze
# 540 540
# it test gold_only
# 461 461
# it test gold_silver
# 461 461
# it test gold_silver_bronze
# 461 461

# %%
False and True
# Out:
# False
